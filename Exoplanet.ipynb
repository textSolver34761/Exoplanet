# %%
import requests
import pandas as pd

# %%
url = "https://data.opendatasoft.com/api/records/1.0/search/?dataset=exoplaneteu_catalog-1%40datastro&q=&sort=updated&facet=discovered&facet=updated&facet=mass&facet=semi_major_axis&facet=eccentricity&facet=inclination&facet=detection_type&facet=molecules&facet=star_name&facet=ra&facet=dec&facet=star_distance&facet=star_metallicity&facet=star_mass&facet=star_radius&facet=star_age&facet=star_magnetic_field&facet=planet_status"

# %%
r = requests.get(url = url)

# %%
data = r.json()
print(data)
# Out:
# {'nhits': 5106, 'parameters': {'dataset': ['exoplaneteu_catalog-1@datastro'], 'rows': 10, 'start': 0, 'sort': ['updated'], 'facet': ['discovered', 'updated', 'mass', 'semi_major_axis', 'eccentricity', 'inclination', 'detection_type', 'molecules', 'star_name', 'ra', 'dec', 'star_distance', 'star_metallicity', 'star_mass', 'star_radius', 'star_age', 'star_magnetic_field', 'planet_status'], 'format': 'json', 'timezone': 'UTC'}, 'records': [{'datasetid': 'exoplaneteu_catalog-1@datastro', 'recordid': '62d82fb93b26b450f23913e05ab0025c0b364f9b', 'fields': {'mass_error_min': 0.52, 'star_distance': 5760.0, 'star_mass_error_min': 0.28, 'semi_major_axis': 4.06, 'publication': 'Published in a refereed paper', 'mass': 0.91, 'star_mass': 0.48, 'star_distance_error_min': 240.0, 'star_mass_error_max': 0.35, 'detection_type': 'Microlensing', 'discovered': '2022', 'mass_detection_type': 'Microlensing', 'name': 'OGLE-2018-BLG-1119 b', 'dec': -32.375277792, 'star_name': 'OGLE-2018-BLG-1119', 'updated': 
# ...

# %%
df = pd.DataFrame(data=data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2344/1954079987.py in <module>
# ----> 1 df = pd.DataFrame(data=data)
#       2 df
#
# c:\Users\benpr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# c:\Users\benpr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# ...
